# %% [markdown]
# # Laboratório 13
#
# Nota: Substitua os seus nomes e informações abaixo antes do envio da atividade. A atividade deve ser enviada no `Moodle` da disciplina, e o arquivo **DEVE** estar no formato `.ipynb`.
#
# [Nome Aluno 1] / [NUSP Aluno 1] / [Vespertino/Noturno]
#
# [Nome Aluno 2] / [NUSP Aluno 2] / [Vespertino/Noturno]

# %% [markdown]
# ## Exercícios

# %% [markdown]
# 1. Importe o banco de tweets

# %% [markdown]
# 2) Filtre as observação não relacionadas às vacinas de Covid-19 e os NAs

# %% [markdown]
# 3) Transforme a coluna de Positions_vac em int e salve o banco de dados com índice resetado.

# %% [markdown]
# 3.a) Recodifique a coluna de positions_vac dos valores [1,2,3] para favorável como 0, neutro como 1 e desfavorável como 2

# %% [markdown]
# 4) Apresente a frequência de observações por classe

# %% [markdown]
# ### Pré-processamento

# %% [markdown]
# 5 - Instale a biblioteca Transformers

# %% [markdown]
# 6 - Importe as bibliotecas Torch e Transformers, junto do modelo e do tokenizador.

# %% [markdown]
# 7 - Instancie o tokenizador do modelo [BERTimbau](https://huggingface.co/neuralmind/bert-base-portuguese-cased)

# %% [markdown]
# ### DataSet e DataLoader

# %% [markdown]
# 8 - Crie o objeto/classe do Dataset de Treino. Defina MAX_LEN em 256

# %% [markdown]
# 9 - Faça um objeto do mesmo tipo para o banco de teste

# %% [markdown]
# 10 - Divida o banco entre treino e teste, deixando 10% para teste. Não esqueça de resetar os indíces.

# %% [markdown]
# 11 - Imprima o tamanho dos bancos de treino e teste

# %% [markdown]
# 12 - Imprima a distribuição das classes no banco de treino

# %% [markdown]
# 13 - Faça o mesmo para o banco de teste

# %% [markdown]
# 15 - Que problemas podem surgir no K-fold devido ao desbalanceamento das classes?

# %% [markdown]
# Resposta:

# %% [markdown]
# ### Modelo

# %% [markdown]
# 16 - Descubra se é possível utilizar a aceleração de GPU e imprima isso com um if/else.

# %% [markdown]
# 17 - Instancie o modelo do BERTimbau. Não esqueça de alterar as opções para o caso em questão

# %% [markdown]
# #### CONFIGS

# %% [markdown]
# 18 - Crie uma célula com as principais configurações de hiperparâmetros. O modelo será treinado com 5-fold cross validation e 5 epochs. Defina o batch_size em 16.

# %% [markdown]
# 19 - Importe as utilidades definidas no laboratório da aula.

# %% [markdown]
# #### Métricas

# %% [markdown]
# 20 - Estabeleça as funções de accuracy e precision, recall e f1. Não se esqueça de alterá-las para o caso em questão.

# %% [markdown]
# 21 - Limpe a memória do CUDA

# %% [markdown]
# ### Loop de Treinamento/Validação

# %% [markdown]
# 22 - Faça o loop de treinamento e validação do Modelo

# %% [markdown]
# ### Resultados de Validação

# %% [markdown]
# 23 - Transforme o dicionário de estatísticas de treinamento em um dataframe e o imprima.

# %% [markdown]
# 24 - Crie um novo dataframe agrupando as métricas por epoch e calculando sua média.

# %% [markdown]
# #### Loss

# %% [markdown]
# 25 - Apresente um gráfico de linha com a loss de treino e validação por epoch.

# %% [markdown]
# 26 - O que essas duas métricas mostram?

# %% [markdown]
# #### Precision

# %% [markdown]
# 27 - Apresente um gráfico de linhas da precision média por classe

# %% [markdown]
# 28 - O que se pode concluir dessa métrica?

# %% [markdown]
# #### Recall

# %% [markdown]
# 29 - Faça um gráfico do recall médio por classe

# %% [markdown]
# 30 - O que se pode concluir?

# %% [markdown]
# #### F1-Score

# %% [markdown]
# 31 - Faça um gráfico do F1-score médio por classe

# %% [markdown]
# 32 - O que se pode concluir com essa métrica?

# %% [markdown]
# ### Resultado no banco de teste

# %% [markdown]
# Vamos agora avaliar os resultados no banco de teste

# %% [markdown]
# 33 - Crie o dalaset de teste e o coloque dentro do dataloader

# %% [markdown]
# 34 - Faça o loop de predições no banco de teste

# %% [markdown]
# 35 - Pegue o ID do fold com o melhor f1_macro

# %% [markdown]
# 36 - Pegue as predições do fold do exercício anterior e as salve em uma variável.

# %% [markdown]
# #### Accuracy no Banco de Teste

# %% [markdown]
# 37 - Calcule a accuracy do melhor modelo

# %% [markdown]
# #### Confusion Matrix

# %% [markdown]
# 38 - Apresente a matriz de confusão do melhor modelo

# %% [markdown]
# #### Classification Report

# %% [markdown]
# 39 - Apresente o relatório de classificação

# %% [markdown]
# 40 - Discuta os resultados
