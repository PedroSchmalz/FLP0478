# %% [markdown]
# # Laboratório 11
#
# Nota: Substitua os seus nomes e informações abaixo antes do envio da atividade. A atividade deve ser enviada no `Moodle` da disciplina, e o arquivo **DEVE** estar no formato `.ipynb`.
#
# [Nome Aluno 1] / [NUSP Aluno 1] / [Vespertino/Noturno]
#
# [Nome Aluno 2] / [NUSP Aluno 2] / [Vespertino/Noturno]

# %% [markdown]
# ## Exercícios

# %% [markdown]
# Agora, você irá rodar um modelo de decision trees na classificação de tweets. Primeiro, vamos importar o banco de dados e pré-processar o texto como fizemos anteriormente.

# %%
import pandas as pd

caminho = 'https://github.com/NUPRAM/CoViD-Pol/raw/main/Covid-Pol_Corpus_v2.0.csv'

df_ex = pd.read_csv(caminho)

df_ex.head()

# %% [markdown]
# Vamos continuar com a classificação de tweets. Nos exercícios, você deve trabalhar a classificação com STANCE (POSICIONAMENTO). Use as três classes.

# %% [markdown]
# 1 - Faça novamente a separação em treino e teste de 'texto' e 'target', colocando STANCE como target e separando 20% para teste. (não se esqueça de filtrar os tweets relevantes).

# %% [markdown]
# 2 - Vetorize o X de Treino

# %% [markdown]
# 3 - Qual a distribuição de STANCE no treino e no teste?

# %% [markdown]
# 4 - Treine um VOTING CLASSIFIER utilizando três modelos como 'eleitores'. Imprima a distribuição de precision, recall e f1-score no K-fold (k = 10). Salve o melhor modelo para que possamos aplicar no banco de teste depois.

# %% [markdown]
# 5 - Aplique o melhor modelo do Voting Classifiers no banco de teste e imprima o relatório de classificação

# %% [markdown]
# 6 - Rode um RANDOM FOREST com quaisquer parâmetros. Imprima a distribuição de precision, recall e f1-score no K-fold (k = 10). Salve o melhor modelo para que possamos aplicar no banco de teste depois.

# %% [markdown]
# 7 - Aplique o melhor modelo do Random Forest no banco de teste e imprima o relatório de classificação

# %% [markdown]
# 8 - Imprima a feature importance do modelo.

# %% [markdown]
# 9 - Usando o ADABoost, faça um gridsearch com parâmetros de sua escolha, tanto para o learner base quanto para o classificador ADABoost. (Use F1-Macro como scoring, ainda mais importante em stance).
#
# **[Se o grid_search estiver demorando muito, reduza o número de parâmetros. Não é o intuito do exercício fazer o melhor modelo possível].**

# %% [markdown]
# 10 - Imprima os melhores parâmetros encontrados no exercício anterior

# %% [markdown]
# 11 - Faça um 10-fold Cross Validation e salve o melhor modelo.

# %% [markdown]
# 12 - Avalie o melhor modelo no banco de teste

# %% [markdown]
# 13 - Faça um Grid search usando o GRADIENT BOOSTING

# %% [markdown]
# 14 - Imprima os melhores parâmetros

# %% [markdown]
# 15 - Faça um 10-fold Cross Validation usando estes parâmetros, imprima os resultados e salvando o melhor modelo.

# %% [markdown]
# 16 - Utilize o melhor modelo no banco de teste e imprima o relatório de classificação
